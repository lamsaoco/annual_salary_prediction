# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

df = pd.read_csv('data_prepared.csv')

df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=42)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=42)
 
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)
df_full_train = df_full_train.reset_index(drop=True)

y_train = np.log1p(df_train['salary_vnd'])
y_val = np.log1p(df_val['salary_vnd'])
y_test = np.log1p(df_test['salary_vnd'])
y_full_train = np.log1p(df_full_train['salary_vnd'])

del df_train['salary_vnd']
del df_val['salary_vnd']
del df_test['salary_vnd']
del df_full_train['salary_vnd']

# %%
import xgboost as xgb
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import root_mean_squared_error, r2_score, mean_absolute_percentage_error

# %%
train_dicts = df_train.to_dict(orient='records')
dv = DictVectorizer(sparse=False)
dv.fit(train_dicts)
X_train = dv.transform(train_dicts)
val_dicts = df_val.to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
features = dv.get_feature_names_out().tolist()

# %%
dtrain = xgb.DMatrix(X_train, label=y_train, feature_names=features)
dval = xgb.DMatrix(X_val, label=y_val, feature_names=features)

# %%
watchlist = [(dtrain, 'train'), (dval, 'val')]
scores = {}

# %%
def parse_xgb_output(output):
    results = []
 
    for line in output.stdout.strip().split('\n'):
        it_line, train_line, val_line = line.split('\t')
 
        it = int(it_line.strip('[]'))
        train = float(train_line.split(':')[1])
        val = float(val_line.split(':')[1])
 
        results.append((it, train, val))
     
    columns = ['num_iter', 'train_rmse', 'val_rmse']
    df_results = pd.DataFrame(results, columns=columns)
    return df_results

# %%
# %%capture output
for e in [0.05, 0.1, 0.3, 0.5, 0.8, 1]:
    xgb_params = {
        'eta': e, 
        'max_depth': 10,
        'min_child_weight': 1,
        
        'objective': 'reg:squarederror',
        'nthread': 8,
        'eval_metric': 'rmse',
        
        'seed': 42,
        'verbosity': 1,
    }
    model = xgb.train(xgb_params, dtrain, num_boost_round=201, verbose_eval=5, evals=watchlist)

    key = 'eta=%s' % (xgb_params['eta'])
    scores[key] = parse_xgb_output(output)

# %%
for e in [0.05, 0.1, 0.3, 0.5, 0.8, 1]:
    cols = 'eta=' + str(e)
    print(cols + '=====================')
    print(scores[cols].sort_values('val_rmse', ascending=True))
    print()
    print()
# Out:
# eta=0.05=====================
#     num_iter  train_rmse  val_rmse
# 10         5     0.28459   0.28598
# 8          9     0.28460   0.28600
# 11         9     0.28347   0.28630
# 15         0     0.28656   0.28663
# 13         5     0.28387   0.28673
# 14         9     0.28262   0.28736
# 16         5     0.28376   0.28755
# 7          5     0.28728   0.28793
# 17         9     0.28237   0.28861
# 12         0     0.29216   0.29232
# 5          9     0.30294   0.30335
# 9          0     0.31989   0.32027
# 4          5     0.32389   0.32438
# 2          9     0.33326   0.33377
# 6          0     0.34887   0.34943
# 1          5     0.35464   0.35524
# 3          0     0.38412   0.38487
# 0          0     0.39372   0.39452
#
#
# eta=0.1=====================
#     num_iter  train_rmse  val_rmse
# 10         5     0.28459   0.28598
# 8          9     0.28460   0.28600
# 11         9     0.28347   0.28630
# 15         0     0.28656   0.28663
# 13         5     0.28387   0.28673
# 14         9     0.28262   0.28736
# 16         5     0.28376   0.28755
# 7          5     0.28728   0.28793
# 17         9     0.28237   0.28861
# 12         0     0.29216   0.29232
# 5          9     0.30294   0.30335
# 9          0     0.31989   0.32027
# 4          5     0.32389   0.32438
# 2          9     0.33326   0.33377
# 6          0     0.34887   0.34943
# 1          5     0.35464   0.35524
# 3          0     0.38412   0.38487
# 0          0     0.39372   0.39452
#
#
# eta=0.3=====================
#     num_iter  train_rmse  val_rmse
# 10         5     0.28459   0.28598
# 8          9     0.28460   0.28600
# 11         9     0.28347   0.28630
# 15         0     0.28656   0.28663
# 13         5     0.28387   0.28673
# 14         9     0.28262   0.28736
# 16         5     0.28376   0.28755
# 7          5     0.28728   0.28793
# 17         9     0.28237   0.28861
# 12         0     0.29216   0.29232
# 5          9     0.30294   0.30335
# 9          0     0.31989   0.32027
# 4          5     0.32389   0.32438
# 2          9     0.33326   0.33377
# 6          0     0.34887   0.34943
# 1          5     0.35464   0.35524
# 3          0     0.38412   0.38487
# 0          0     0.39372   0.39452
#
#
# eta=0.5=====================
#     num_iter  train_rmse  val_rmse
# 10         5     0.28459   0.28598
# 8          9     0.28460   0.28600
# 11         9     0.28347   0.28630
# 15         0     0.28656   0.28663
# 13         5     0.28387   0.28673
# 14         9     0.28262   0.28736
# 16         5     0.28376   0.28755
# 7          5     0.28728   0.28793
# 17         9     0.28237   0.28861
# 12         0     0.29216   0.29232
# 5          9     0.30294   0.30335
# 9          0     0.31989   0.32027
# 4          5     0.32389   0.32438
# 2          9     0.33326   0.33377
# 6          0     0.34887   0.34943
# 1          5     0.35464   0.35524
# 3          0     0.38412   0.38487
# 0          0     0.39372   0.39452
#
#
# eta=0.8=====================
#     num_iter  train_rmse  val_rmse
# 10         5     0.28459   0.28598
# 8          9     0.28460   0.28600
# 11         9     0.28347   0.28630
# 15         0     0.28656   0.28663
# 13         5     0.28387   0.28673
# 14         9     0.28262   0.28736
# 16         5     0.28376   0.28755
# 7          5     0.28728   0.28793
# 17         9     0.28237   0.28861
# 12         0     0.29216   0.29232
# 5          9     0.30294   0.30335
# 9          0     0.31989   0.32027
# 4          5     0.32389   0.32438
# 2          9     0.33326   0.33377
# 6          0     0.34887   0.34943
# 1          5     0.35464   0.35524
# 3          0     0.38412   0.38487
# 0          0     0.39372   0.39452
#
#
# eta=1=====================
#     num_iter  train_rmse  val_rmse
# 10         5     0.28459   0.28598
# 8          9     0.28460   0.28600
# 11         9     0.28347   0.28630
# 15         0     0.28656   0.28663
# 13         5     0.28387   0.28673
# 14         9     0.28262   0.28736
# 16         5     0.28376   0.28755
# 7          5     0.28728   0.28793
# 17         9     0.28237   0.28861
# 12         0     0.29216   0.29232
# 5          9     0.30294   0.30335
# 9          0     0.31989   0.32027
# 4          5     0.32389   0.32438
# 2          9     0.33326   0.33377
# 6          0     0.34887   0.34943
# 1          5     0.35464   0.35524
# 3          0     0.38412   0.38487
# 0          0     0.39372   0.39452

# %%
for e in [0.05, 0.1, 0.3, 0.5, 0.8, 1]:
    xgb_params = {
        'eta': e, 
        'max_depth': 10,
        'min_child_weight': 1,
        
        'objective': 'reg:squarederror',
        'nthread': 8,
        'eval_metric': ['rmse', 'mape', 'mae'],
        
        'seed': 42,
        'verbosity': 1,
    }
    model = xgb.train(xgb_params, dtrain, num_boost_round=200, verbose_eval=5, evals=watchlist)
# Out:
# [0]	train-rmse:0.39372	train-mape:0.01635	train-mae:0.31617	val-rmse:0.39452	val-mape:0.01639	val-mae:0.31690
# [5]	train-rmse:0.35464	train-mape:0.01496	train-mae:0.28907	val-rmse:0.35524	val-mape:0.01499	val-mae:0.28961
# [10]	train-rmse:0.32898	train-mape:0.01407	train-mae:0.27167	val-rmse:0.32949	val-mape:0.01409	val-mae:0.27204
# [15]	train-rmse:0.31255	train-mape:0.01351	train-mae:0.26079	val-rmse:0.31298	val-mape:0.01353	val-mae:0.26106
# [20]	train-rmse:0.30216	train-mape:0.01317	train-mae:0.25404	val-rmse:0.30258	val-mape:0.01318	val-mae:0.25430
# [25]	train-rmse:0.29567	train-mape:0.01296	train-mae:0.24984	val-rmse:0.29611	val-mape:0.01297	val-mae:0.25015
# [30]	train-rmse:0.29162	train-mape:0.01282	train-mae:0.24720	val-rmse:0.29211	val-mape:0.01284	val-mae:0.24757
# [35]	train-rmse:0.28902	train-mape:0.01274	train-mae:0.24547	val-rmse:0.28961	val-mape:0.01276	val-mae:0.24593
# [40]	train-rmse:0.28737	train-mape:0.01268	train-mae:0.24434	val-rmse:0.28807	val-mape:0.01271	val-mae:0.24492
# [45]	train-rmse:0.28631	train-mape:0.01264	train-mae:0.24360	val-rmse:0.28715	val-mape:0.01268	val-mae:0.24431
# [50]	train-rmse:0.28563	train-mape:0.01262	train-mae:0.24312	val-rmse:0.28660	val-mape:0.01266	val-mae:0.24394
# [55]	train-rmse:0.28516	train-mape:0.01260	train-mae:0.24278	val-rmse:0.28627	val-mape:0.01265	val-mae:0.24372
# [60]	train-rmse:0.28484	train-mape:0.01259	train-mae:0.24252	val-rmse:0.28609	val-mape:0.01264	val-mae:0.24358
# [65]	train-rmse:0.28461	train-mape:0.01258	train-mae:0.24233	val-rmse:0.28598	val-mape:0.01264	val-mae:0.24350
# [70]	train-rmse:0.28441	train-mape:0.01257	train-mae:0.24216	val-rmse:0.28593	val-mape:0.01263	val-mae:0.24346
# [75]	train-rmse:0.28425	train-mape:0.01256	train-mae:0.24202	val-rmse:0.28590	val-mape:0.01263	val-mae:0.24343
# [80]	train-rmse:0.28412	train-mape:0.01256	train-mae:0.24191	val-rmse:0.28588	val-mape:0.01263	val-mae:0.24341
# [85]	train-rmse:0.28398	train-mape:0.01255	train-mae:0.24177	val-rmse:0.28589	val-mape:0.01263	val-mae:0.24340
# [90]	train-rmse:0.28383	train-mape:0.01254	train-mae:0.24163	val-rmse:0.28590	val-mape:0.01263	val-mae:0.24340
# [95]	train-rmse:0.28368	train-mape:0.01254	train-mae:0.24149	val-rmse:0.28590	val-mape:0.01263	val-mae:0.24340
# [100]	train-rmse:0.28352	train-mape:0.01253	train-mae:0.24135	val-rmse:0.28592	val-mape:0.01263	val-mae:0.24341
# [105]	train-rmse:0.28341	train-mape:0.01252	train-mae:0.24125	val-rmse:0.28593	val-mape:0.01263	val-mae:0.24341
# [110]	train-rmse:0.28330	train-mape:0.01252	train-mae:0.24114	val-rmse:0.28594	val-mape:0.01263	val-mae:0.24342
# [115]	train-rmse:0.28318	train-mape:0.01251	train-mae:0.24104	val-rmse:0.28596	val-mape:0.01263	val-mae:0.24343
# [120]	train-rmse:0.28307	train-mape:0.01251	train-mae:0.24094	val-rmse:0.28598	val-mape:0.01263	val-mae:0.24345
# [125]	train-rmse:0.28296	train-mape:0.01250	train-mae:0.24084	val-rmse:0.28599	val-mape:0.01264	val-mae:0.24346
# [130]	train-rmse:0.28285	train-mape:0.01250	train-mae:0.24074	val-rmse:0.28600	val-mape:0.01264	val-mae:0.24347
# [135]	train-rmse:0.28275	train-mape:0.01249	train-mae:0.24065	val-rmse:0.28602	val-mape:0.01264	val-mae:0.24348
# [140]	train-rmse:0.28264	train-mape:0.01249	train-mae:0.24055	val-rmse:0.28604	val-mape:0.01264	val-mae:0.24349
# [145]	train-rmse:0.28252	train-mape:0.01248	train-mae:0.24045	val-rmse:0.28605	val-mape:0.01264	val-mae:0.24350
# [150]	train-rmse:0.28240	train-mape:0.01247	train-mae:0.24033	val-rmse:0.28606	val-mape:0.01264	val-mae:0.24351
# [155]	train-rmse:0.28229	train-mape:0.01247	train-mae:0.24023	val-rmse:0.28608	val-mape:0.01264	val-mae:0.24352
# [160]	train-rmse:0.28218	train-mape:0.01246	train-mae:0.24013	val-rmse:0.28609	val-mape:0.01264	val-mae:0.24353
# [165]	train-rmse:0.28208	train-mape:0.01246	train-mae:0.24004	val-rmse:0.28610	val-mape:0.01264	val-mae:0.24354
# [170]	train-rmse:0.28196	train-mape:0.01245	train-mae:0.23994	val-rmse:0.28612	val-mape:0.01264	val-mae:0.24355
# [175]	train-rmse:0.28185	train-mape:0.01245	train-mae:0.23983	val-rmse:0.28613	val-mape:0.01264	val-mae:0.24356
# [180]	train-rmse:0.28175	train-mape:0.01244	train-mae:0.23974	val-rmse:0.28615	val-mape:0.01264	val-mae:0.24357
# [185]	train-rmse:0.28164	train-mape:0.01244	train-mae:0.23964	val-rmse:0.28616	val-mape:0.01264	val-mae:0.24358
# [190]	train-rmse:0.28152	train-mape:0.01243	train-mae:0.23954	val-rmse:0.28617	val-mape:0.01264	val-mae:0.24359
# [195]	train-rmse:0.28144	train-mape:0.01243	train-mae:0.23946	val-rmse:0.28619	val-mape:0.01264	val-mae:0.24360
# [199]	train-rmse:0.28134	train-mape:0.01242	train-mae:0.23937	val-rmse:0.28620	val-mape:0.01264	val-mae:0.24360
# [0]	train-rmse:0.38412	train-mape:0.01600	train-mae:0.30942	val-rmse:0.38487	val-mape:0.01604	val-mae:0.31010
# [5]	train-rmse:0.32389	train-mape:0.01390	train-mae:0.26826	val-rmse:0.32438	val-mape:0.01391	val-mae:0.26860
# [10]	train-rmse:0.29976	train-mape:0.01309	train-mae:0.25249	val-rmse:0.30018	val-mape:0.01311	val-mae:0.25276
# [15]	train-rmse:0.29055	train-mape:0.01279	train-mae:0.24650	val-rmse:0.29104	val-mape:0.01281	val-mae:0.24688
# [20]	train-rmse:0.28687	train-mape:0.01266	train-mae:0.24400	val-rmse:0.28760	val-mape:0.01269	val-mae:0.24461
# [25]	train-rmse:0.28541	train-mape:0.01261	train-mae:0.24296	val-rmse:0.28640	val-mape:0.01265	val-mae:0.24381
# [30]	train-rmse:0.28473	train-mape:0.01258	train-mae:0.24244	val-rmse:0.28602	val-mape:0.01264	val-mae:0.24353
# [35]	train-rmse:0.28435	train-mape:0.01257	train-mae:0.24211	val-rmse:0.28589	val-mape:0.01263	val-mae:0.24342
# [40]	train-rmse:0.28404	train-mape:0.01255	train-mae:0.24183	val-rmse:0.28588	val-mape:0.01263	val-mae:0.24340
# [45]	train-rmse:0.28375	train-mape:0.01254	train-mae:0.24156	val-rmse:0.28590	val-mape:0.01263	val-mae:0.24340
# [50]	train-rmse:0.28343	train-mape:0.01252	train-mae:0.24127	val-rmse:0.28592	val-mape:0.01263	val-mae:0.24341
# [55]	train-rmse:0.28318	train-mape:0.01251	train-mae:0.24104	val-rmse:0.28595	val-mape:0.01263	val-mae:0.24343
# [60]	train-rmse:0.28296	train-mape:0.01250	train-mae:0.24084	val-rmse:0.28598	val-mape:0.01263	val-mae:0.24345
# [65]	train-rmse:0.28272	train-mape:0.01249	train-mae:0.24062	val-rmse:0.28601	val-mape:0.01264	val-mae:0.24347
# [70]	train-rmse:0.28252	train-mape:0.01248	train-mae:0.24044	val-rmse:0.28604	val-mape:0.01264	val-mae:0.24349
# [75]	train-rmse:0.28229	train-mape:0.01247	train-mae:0.24023	val-rmse:0.28606	val-mape:0.01264	val-mae:0.24350
# [80]	train-rmse:0.28204	train-mape:0.01246	train-mae:0.24000	val-rmse:0.28610	val-mape:0.01264	val-mae:0.24353
# [85]	train-rmse:0.28182	train-mape:0.01245	train-mae:0.23980	val-rmse:0.28613	val-mape:0.01264	val-mae:0.24355
# [90]	train-rmse:0.28158	train-mape:0.01244	train-mae:0.23958	val-rmse:0.28616	val-mape:0.01264	val-mae:0.24357
# [95]	train-rmse:0.28137	train-mape:0.01243	train-mae:0.23939	val-rmse:0.28618	val-mape:0.01264	val-mae:0.24359
# [100]	train-rmse:0.28115	train-mape:0.01242	train-mae:0.23918	val-rmse:0.28621	val-mape:0.01264	val-mae:0.24361
# [105]	train-rmse:0.28093	train-mape:0.01240	train-mae:0.23899	val-rmse:0.28625	val-mape:0.01264	val-mae:0.24364
# [110]	train-rmse:0.28068	train-mape:0.01239	train-mae:0.23876	val-rmse:0.28628	val-mape:0.01265	val-mae:0.24366
# [115]	train-rmse:0.28049	train-mape:0.01238	train-mae:0.23859	val-rmse:0.28632	val-mape:0.01265	val-mae:0.24368
# [120]	train-rmse:0.28028	train-mape:0.01237	train-mae:0.23840	val-rmse:0.28637	val-mape:0.01265	val-mae:0.24372
# [125]	train-rmse:0.28007	train-mape:0.01236	train-mae:0.23821	val-rmse:0.28642	val-mape:0.01265	val-mae:0.24375
# [130]	train-rmse:0.27988	train-mape:0.01235	train-mae:0.23803	val-rmse:0.28646	val-mape:0.01265	val-mae:0.24378
# [135]	train-rmse:0.27966	train-mape:0.01234	train-mae:0.23782	val-rmse:0.28649	val-mape:0.01265	val-mae:0.24381
# [140]	train-rmse:0.27947	train-mape:0.01233	train-mae:0.23764	val-rmse:0.28653	val-mape:0.01266	val-mae:0.24384
# [145]	train-rmse:0.27926	train-mape:0.01232	train-mae:0.23745	val-rmse:0.28657	val-mape:0.01266	val-mae:0.24386
# [150]	train-rmse:0.27905	train-mape:0.01231	train-mae:0.23725	val-rmse:0.28662	val-mape:0.01266	val-mae:0.24389
# [155]	train-rmse:0.27885	train-mape:0.01230	train-mae:0.23706	val-rmse:0.28666	val-mape:0.01266	val-mae:0.24391
# [160]	train-rmse:0.27866	train-mape:0.01230	train-mae:0.23689	val-rmse:0.28670	val-mape:0.01266	val-mae:0.24394
# [165]	train-rmse:0.27849	train-mape:0.01229	train-mae:0.23673	val-rmse:0.28674	val-mape:0.01266	val-mae:0.24395
# [170]	train-rmse:0.27826	train-mape:0.01228	train-mae:0.23652	val-rmse:0.28679	val-mape:0.01266	val-mae:0.24399
# [175]	train-rmse:0.27811	train-mape:0.01227	train-mae:0.23637	val-rmse:0.28683	val-mape:0.01266	val-mae:0.24402
# [180]	train-rmse:0.27790	train-mape:0.01226	train-mae:0.23618	val-rmse:0.28687	val-mape:0.01267	val-mae:0.24405
# [185]	train-rmse:0.27774	train-mape:0.01225	train-mae:0.23603	val-rmse:0.28690	val-mape:0.01267	val-mae:0.24406
# [190]	train-rmse:0.27757	train-mape:0.01224	train-mae:0.23587	val-rmse:0.28695	val-mape:0.01267	val-mae:0.24409
# [195]	train-rmse:0.27739	train-mape:0.01223	train-mae:0.23571	val-rmse:0.28698	val-mape:0.01267	val-mae:0.24411
# [199]	train-rmse:0.27725	train-mape:0.01223	train-mae:0.23558	val-rmse:0.28702	val-mape:0.01267	val-mae:0.24412
# [0]	train-rmse:0.34887	train-mape:0.01476	train-mae:0.28513	val-rmse:0.34943	val-mape:0.01478	val-mae:0.28562
# [5]	train-rmse:0.28728	train-mape:0.01268	train-mae:0.24429	val-rmse:0.28793	val-mape:0.01270	val-mae:0.24482
# [10]	train-rmse:0.28437	train-mape:0.01257	train-mae:0.24210	val-rmse:0.28596	val-mape:0.01264	val-mae:0.24348
# [15]	train-rmse:0.28350	train-mape:0.01252	train-mae:0.24129	val-rmse:0.28605	val-mape:0.01264	val-mae:0.24351
# [20]	train-rmse:0.28281	train-mape:0.01249	train-mae:0.24065	val-rmse:0.28621	val-mape:0.01264	val-mae:0.24362
# [25]	train-rmse:0.28208	train-mape:0.01246	train-mae:0.23996	val-rmse:0.28632	val-mape:0.01265	val-mae:0.24368
# [30]	train-rmse:0.28140	train-mape:0.01242	train-mae:0.23932	val-rmse:0.28645	val-mape:0.01265	val-mae:0.24377
# [35]	train-rmse:0.28066	train-mape:0.01239	train-mae:0.23864	val-rmse:0.28666	val-mape:0.01266	val-mae:0.24391
# [40]	train-rmse:0.28003	train-mape:0.01236	train-mae:0.23806	val-rmse:0.28677	val-mape:0.01266	val-mae:0.24396
# [45]	train-rmse:0.27937	train-mape:0.01232	train-mae:0.23744	val-rmse:0.28694	val-mape:0.01267	val-mae:0.24408
# [50]	train-rmse:0.27882	train-mape:0.01230	train-mae:0.23693	val-rmse:0.28707	val-mape:0.01267	val-mae:0.24414
# [55]	train-rmse:0.27818	train-mape:0.01227	train-mae:0.23632	val-rmse:0.28721	val-mape:0.01267	val-mae:0.24421
# [60]	train-rmse:0.27749	train-mape:0.01223	train-mae:0.23568	val-rmse:0.28736	val-mape:0.01268	val-mae:0.24431
# [65]	train-rmse:0.27696	train-mape:0.01221	train-mae:0.23516	val-rmse:0.28747	val-mape:0.01268	val-mae:0.24437
# [70]	train-rmse:0.27631	train-mape:0.01218	train-mae:0.23457	val-rmse:0.28764	val-mape:0.01269	val-mae:0.24446
# [75]	train-rmse:0.27571	train-mape:0.01215	train-mae:0.23400	val-rmse:0.28781	val-mape:0.01269	val-mae:0.24458
# [80]	train-rmse:0.27505	train-mape:0.01211	train-mae:0.23341	val-rmse:0.28798	val-mape:0.01270	val-mae:0.24467
# [85]	train-rmse:0.27430	train-mape:0.01208	train-mae:0.23273	val-rmse:0.28815	val-mape:0.01270	val-mae:0.24477
# [90]	train-rmse:0.27361	train-mape:0.01205	train-mae:0.23210	val-rmse:0.28830	val-mape:0.01271	val-mae:0.24485
# [95]	train-rmse:0.27310	train-mape:0.01202	train-mae:0.23161	val-rmse:0.28841	val-mape:0.01271	val-mae:0.24490
# [100]	train-rmse:0.27257	train-mape:0.01200	train-mae:0.23111	val-rmse:0.28854	val-mape:0.01271	val-mae:0.24496
# [105]	train-rmse:0.27204	train-mape:0.01197	train-mae:0.23061	val-rmse:0.28868	val-mape:0.01272	val-mae:0.24505
# [110]	train-rmse:0.27163	train-mape:0.01195	train-mae:0.23021	val-rmse:0.28880	val-mape:0.01272	val-mae:0.24512
# [115]	train-rmse:0.27098	train-mape:0.01192	train-mae:0.22960	val-rmse:0.28896	val-mape:0.01273	val-mae:0.24522
# [120]	train-rmse:0.27036	train-mape:0.01189	train-mae:0.22903	val-rmse:0.28911	val-mape:0.01273	val-mae:0.24530
# [125]	train-rmse:0.26980	train-mape:0.01186	train-mae:0.22851	val-rmse:0.28925	val-mape:0.01273	val-mae:0.24537
# [130]	train-rmse:0.26932	train-mape:0.01184	train-mae:0.22805	val-rmse:0.28937	val-mape:0.01274	val-mae:0.24545
# [135]	train-rmse:0.26877	train-mape:0.01181	train-mae:0.22752	val-rmse:0.28953	val-mape:0.01274	val-mae:0.24553
# [140]	train-rmse:0.26821	train-mape:0.01178	train-mae:0.22700	val-rmse:0.28968	val-mape:0.01275	val-mae:0.24562
# [145]	train-rmse:0.26767	train-mape:0.01175	train-mae:0.22649	val-rmse:0.28983	val-mape:0.01275	val-mae:0.24570
# [150]	train-rmse:0.26719	train-mape:0.01173	train-mae:0.22604	val-rmse:0.29000	val-mape:0.01276	val-mae:0.24580
# [155]	train-rmse:0.26662	train-mape:0.01170	train-mae:0.22550	val-rmse:0.29015	val-mape:0.01276	val-mae:0.24591
# [160]	train-rmse:0.26607	train-mape:0.01168	train-mae:0.22499	val-rmse:0.29031	val-mape:0.01277	val-mae:0.24602
# [165]	train-rmse:0.26566	train-mape:0.01166	train-mae:0.22461	val-rmse:0.29045	val-mape:0.01277	val-mae:0.24611
# [170]	train-rmse:0.26519	train-mape:0.01163	train-mae:0.22416	val-rmse:0.29056	val-mape:0.01278	val-mae:0.24616
# [175]	train-rmse:0.26465	train-mape:0.01161	train-mae:0.22366	val-rmse:0.29073	val-mape:0.01278	val-mae:0.24628
# [180]	train-rmse:0.26412	train-mape:0.01158	train-mae:0.22316	val-rmse:0.29084	val-mape:0.01278	val-mae:0.24634
# [185]	train-rmse:0.26363	train-mape:0.01156	train-mae:0.22269	val-rmse:0.29098	val-mape:0.01279	val-mae:0.24642
# [190]	train-rmse:0.26315	train-mape:0.01153	train-mae:0.22225	val-rmse:0.29113	val-mape:0.01279	val-mae:0.24651
# [195]	train-rmse:0.26271	train-mape:0.01151	train-mae:0.22183	val-rmse:0.29125	val-mape:0.01280	val-mae:0.24657
# [199]	train-rmse:0.26235	train-mape:0.01149	train-mae:0.22149	val-rmse:0.29137	val-mape:0.01280	val-mae:0.24664
# [0]	train-rmse:0.31989	train-mape:0.01376	train-mae:0.26560	val-rmse:0.32027	val-mape:0.01377	val-mae:0.26584
# [5]	train-rmse:0.28459	train-mape:0.01257	train-mae:0.24224	val-rmse:0.28598	val-mape:0.01264	val-mae:0.24347
# [10]	train-rmse:0.28328	train-mape:0.01251	train-mae:0.24096	val-rmse:0.28637	val-mape:0.01265	val-mae:0.24371
# [15]	train-rmse:0.28219	train-mape:0.01245	train-mae:0.23991	val-rmse:0.28663	val-mape:0.01266	val-mae:0.24386
# [20]	train-rmse:0.28094	train-mape:0.01239	train-mae:0.23872	val-rmse:0.28704	val-mape:0.01267	val-mae:0.24411
# [25]	train-rmse:0.27979	train-mape:0.01233	train-mae:0.23761	val-rmse:0.28744	val-mape:0.01268	val-mae:0.24439
# [30]	train-rmse:0.27883	train-mape:0.01228	train-mae:0.23668	val-rmse:0.28780	val-mape:0.01270	val-mae:0.24462
# [35]	train-rmse:0.27791	train-mape:0.01224	train-mae:0.23580	val-rmse:0.28819	val-mape:0.01271	val-mae:0.24488
# [40]	train-rmse:0.27687	train-mape:0.01219	train-mae:0.23480	val-rmse:0.28854	val-mape:0.01272	val-mae:0.24508
# [45]	train-rmse:0.27582	train-mape:0.01213	train-mae:0.23378	val-rmse:0.28887	val-mape:0.01273	val-mae:0.24525
# [50]	train-rmse:0.27476	train-mape:0.01208	train-mae:0.23278	val-rmse:0.28914	val-mape:0.01274	val-mae:0.24540
# [55]	train-rmse:0.27372	train-mape:0.01203	train-mae:0.23177	val-rmse:0.28952	val-mape:0.01275	val-mae:0.24561
# [60]	train-rmse:0.27280	train-mape:0.01198	train-mae:0.23090	val-rmse:0.28979	val-mape:0.01275	val-mae:0.24573
# [65]	train-rmse:0.27190	train-mape:0.01194	train-mae:0.23001	val-rmse:0.29011	val-mape:0.01276	val-mae:0.24593
# [70]	train-rmse:0.27094	train-mape:0.01189	train-mae:0.22910	val-rmse:0.29040	val-mape:0.01277	val-mae:0.24613
# [75]	train-rmse:0.26984	train-mape:0.01184	train-mae:0.22808	val-rmse:0.29073	val-mape:0.01278	val-mae:0.24634
# [80]	train-rmse:0.26894	train-mape:0.01179	train-mae:0.22721	val-rmse:0.29103	val-mape:0.01279	val-mae:0.24650
# [85]	train-rmse:0.26810	train-mape:0.01175	train-mae:0.22640	val-rmse:0.29133	val-mape:0.01280	val-mae:0.24667
# [90]	train-rmse:0.26724	train-mape:0.01171	train-mae:0.22555	val-rmse:0.29161	val-mape:0.01281	val-mae:0.24682
# [95]	train-rmse:0.26639	train-mape:0.01166	train-mae:0.22475	val-rmse:0.29192	val-mape:0.01282	val-mae:0.24702
# [100]	train-rmse:0.26559	train-mape:0.01162	train-mae:0.22397	val-rmse:0.29216	val-mape:0.01283	val-mae:0.24716
# [105]	train-rmse:0.26475	train-mape:0.01158	train-mae:0.22315	val-rmse:0.29243	val-mape:0.01283	val-mae:0.24729
# [110]	train-rmse:0.26400	train-mape:0.01154	train-mae:0.22240	val-rmse:0.29270	val-mape:0.01284	val-mae:0.24743
# [115]	train-rmse:0.26320	train-mape:0.01150	train-mae:0.22162	val-rmse:0.29298	val-mape:0.01285	val-mae:0.24761
# [120]	train-rmse:0.26248	train-mape:0.01146	train-mae:0.22091	val-rmse:0.29326	val-mape:0.01286	val-mae:0.24775
# [125]	train-rmse:0.26161	train-mape:0.01142	train-mae:0.22006	val-rmse:0.29362	val-mape:0.01287	val-mae:0.24799
# [130]	train-rmse:0.26093	train-mape:0.01139	train-mae:0.21940	val-rmse:0.29385	val-mape:0.01288	val-mae:0.24813
# [135]	train-rmse:0.26005	train-mape:0.01134	train-mae:0.21854	val-rmse:0.29417	val-mape:0.01289	val-mae:0.24830
# [140]	train-rmse:0.25940	train-mape:0.01131	train-mae:0.21791	val-rmse:0.29443	val-mape:0.01290	val-mae:0.24847
# [145]	train-rmse:0.25859	train-mape:0.01127	train-mae:0.21713	val-rmse:0.29474	val-mape:0.01291	val-mae:0.24870
# [150]	train-rmse:0.25787	train-mape:0.01123	train-mae:0.21641	val-rmse:0.29500	val-mape:0.01291	val-mae:0.24884
# [155]	train-rmse:0.25711	train-mape:0.01119	train-mae:0.21568	val-rmse:0.29523	val-mape:0.01292	val-mae:0.24894
# [160]	train-rmse:0.25654	train-mape:0.01116	train-mae:0.21511	val-rmse:0.29541	val-mape:0.01293	val-mae:0.24905
# [165]	train-rmse:0.25569	train-mape:0.01112	train-mae:0.21428	val-rmse:0.29574	val-mape:0.01294	val-mae:0.24925
# [170]	train-rmse:0.25503	train-mape:0.01109	train-mae:0.21363	val-rmse:0.29602	val-mape:0.01294	val-mae:0.24942
# [175]	train-rmse:0.25439	train-mape:0.01105	train-mae:0.21298	val-rmse:0.29626	val-mape:0.01295	val-mae:0.24958
# [180]	train-rmse:0.25366	train-mape:0.01102	train-mae:0.21227	val-rmse:0.29650	val-mape:0.01296	val-mae:0.24974
# [185]	train-rmse:0.25308	train-mape:0.01099	train-mae:0.21170	val-rmse:0.29672	val-mape:0.01297	val-mae:0.24987
# [190]	train-rmse:0.25242	train-mape:0.01095	train-mae:0.21103	val-rmse:0.29694	val-mape:0.01297	val-mae:0.25000
# [195]	train-rmse:0.25175	train-mape:0.01092	train-mae:0.21037	val-rmse:0.29720	val-mape:0.01298	val-mae:0.25015
# [199]	train-rmse:0.25118	train-mape:0.01089	train-mae:0.20981	val-rmse:0.29738	val-mape:0.01299	val-mae:0.25026
# [0]	train-rmse:0.29216	train-mape:0.01285	train-mae:0.24763	val-rmse:0.29232	val-mape:0.01285	val-mae:0.24769
# [5]	train-rmse:0.28387	train-mape:0.01253	train-mae:0.24139	val-rmse:0.28673	val-mape:0.01266	val-mae:0.24388
# [10]	train-rmse:0.28229	train-mape:0.01244	train-mae:0.23976	val-rmse:0.28753	val-mape:0.01268	val-mae:0.24435
# [15]	train-rmse:0.28058	train-mape:0.01235	train-mae:0.23800	val-rmse:0.28856	val-mape:0.01272	val-mae:0.24500
# [20]	train-rmse:0.27905	train-mape:0.01227	train-mae:0.23639	val-rmse:0.28941	val-mape:0.01274	val-mae:0.24553
# [25]	train-rmse:0.27761	train-mape:0.01219	train-mae:0.23488	val-rmse:0.29018	val-mape:0.01277	val-mae:0.24600
# [30]	train-rmse:0.27589	train-mape:0.01210	train-mae:0.23312	val-rmse:0.29119	val-mape:0.01280	val-mae:0.24667
# [35]	train-rmse:0.27430	train-mape:0.01201	train-mae:0.23149	val-rmse:0.29190	val-mape:0.01282	val-mae:0.24703
# [40]	train-rmse:0.27292	train-mape:0.01194	train-mae:0.23006	val-rmse:0.29262	val-mape:0.01284	val-mae:0.24748
# [45]	train-rmse:0.27162	train-mape:0.01187	train-mae:0.22871	val-rmse:0.29333	val-mape:0.01287	val-mae:0.24792
# [50]	train-rmse:0.27026	train-mape:0.01180	train-mae:0.22732	val-rmse:0.29403	val-mape:0.01289	val-mae:0.24831
# [55]	train-rmse:0.26887	train-mape:0.01172	train-mae:0.22591	val-rmse:0.29479	val-mape:0.01291	val-mae:0.24872
# [60]	train-rmse:0.26756	train-mape:0.01165	train-mae:0.22456	val-rmse:0.29547	val-mape:0.01293	val-mae:0.24912
# [65]	train-rmse:0.26635	train-mape:0.01159	train-mae:0.22331	val-rmse:0.29617	val-mape:0.01295	val-mae:0.24956
# [70]	train-rmse:0.26515	train-mape:0.01153	train-mae:0.22210	val-rmse:0.29679	val-mape:0.01297	val-mae:0.24994
# [75]	train-rmse:0.26406	train-mape:0.01147	train-mae:0.22098	val-rmse:0.29734	val-mape:0.01299	val-mae:0.25027
# [80]	train-rmse:0.26272	train-mape:0.01140	train-mae:0.21962	val-rmse:0.29797	val-mape:0.01301	val-mae:0.25064
# [85]	train-rmse:0.26141	train-mape:0.01133	train-mae:0.21830	val-rmse:0.29867	val-mape:0.01303	val-mae:0.25108
# [90]	train-rmse:0.26029	train-mape:0.01127	train-mae:0.21718	val-rmse:0.29914	val-mape:0.01305	val-mae:0.25138
# [95]	train-rmse:0.25906	train-mape:0.01121	train-mae:0.21596	val-rmse:0.29966	val-mape:0.01306	val-mae:0.25166
# [100]	train-rmse:0.25786	train-mape:0.01114	train-mae:0.21473	val-rmse:0.30028	val-mape:0.01308	val-mae:0.25199
# [105]	train-rmse:0.25667	train-mape:0.01108	train-mae:0.21356	val-rmse:0.30082	val-mape:0.01309	val-mae:0.25230
# [110]	train-rmse:0.25552	train-mape:0.01102	train-mae:0.21243	val-rmse:0.30141	val-mape:0.01311	val-mae:0.25265
# [115]	train-rmse:0.25450	train-mape:0.01097	train-mae:0.21139	val-rmse:0.30185	val-mape:0.01313	val-mae:0.25292
# [120]	train-rmse:0.25344	train-mape:0.01091	train-mae:0.21031	val-rmse:0.30236	val-mape:0.01314	val-mae:0.25323
# [125]	train-rmse:0.25235	train-mape:0.01086	train-mae:0.20922	val-rmse:0.30296	val-mape:0.01316	val-mae:0.25359
# [130]	train-rmse:0.25129	train-mape:0.01080	train-mae:0.20816	val-rmse:0.30348	val-mape:0.01318	val-mae:0.25391
# [135]	train-rmse:0.25014	train-mape:0.01074	train-mae:0.20698	val-rmse:0.30406	val-mape:0.01320	val-mae:0.25431
# [140]	train-rmse:0.24902	train-mape:0.01068	train-mae:0.20586	val-rmse:0.30460	val-mape:0.01322	val-mae:0.25465
# [145]	train-rmse:0.24810	train-mape:0.01063	train-mae:0.20493	val-rmse:0.30501	val-mape:0.01323	val-mae:0.25492
# [150]	train-rmse:0.24714	train-mape:0.01058	train-mae:0.20395	val-rmse:0.30549	val-mape:0.01325	val-mae:0.25525
# [155]	train-rmse:0.24615	train-mape:0.01053	train-mae:0.20296	val-rmse:0.30599	val-mape:0.01326	val-mae:0.25556
# [160]	train-rmse:0.24517	train-mape:0.01048	train-mae:0.20195	val-rmse:0.30651	val-mape:0.01328	val-mae:0.25589
# [165]	train-rmse:0.24421	train-mape:0.01043	train-mae:0.20100	val-rmse:0.30704	val-mape:0.01330	val-mae:0.25625
# [170]	train-rmse:0.24305	train-mape:0.01037	train-mae:0.19986	val-rmse:0.30768	val-mape:0.01332	val-mae:0.25667
# [175]	train-rmse:0.24213	train-mape:0.01032	train-mae:0.19893	val-rmse:0.30822	val-mape:0.01334	val-mae:0.25703
# [180]	train-rmse:0.24121	train-mape:0.01027	train-mae:0.19800	val-rmse:0.30864	val-mape:0.01335	val-mae:0.25728
# [185]	train-rmse:0.24037	train-mape:0.01023	train-mae:0.19716	val-rmse:0.30900	val-mape:0.01336	val-mae:0.25747
# [190]	train-rmse:0.23954	train-mape:0.01019	train-mae:0.19632	val-rmse:0.30939	val-mape:0.01337	val-mae:0.25770
# [195]	train-rmse:0.23870	train-mape:0.01014	train-mae:0.19548	val-rmse:0.30975	val-mape:0.01338	val-mae:0.25788
# [199]	train-rmse:0.23799	train-mape:0.01011	train-mae:0.19477	val-rmse:0.31011	val-mape:0.01339	val-mae:0.25807
# [0]	train-rmse:0.28656	train-mape:0.01266	train-mae:0.24398	val-rmse:0.28663	val-mape:0.01266	val-mae:0.24392
# [5]	train-rmse:0.28376	train-mape:0.01252	train-mae:0.24118	val-rmse:0.28755	val-mape:0.01269	val-mae:0.24442
# [10]	train-rmse:0.28199	train-mape:0.01241	train-mae:0.23920	val-rmse:0.28895	val-mape:0.01273	val-mae:0.24523
# [15]	train-rmse:0.28020	train-mape:0.01231	train-mae:0.23725	val-rmse:0.29029	val-mape:0.01277	val-mae:0.24607
# [20]	train-rmse:0.27849	train-mape:0.01222	train-mae:0.23538	val-rmse:0.29153	val-mape:0.01281	val-mae:0.24682
# [25]	train-rmse:0.27683	train-mape:0.01212	train-mae:0.23357	val-rmse:0.29271	val-mape:0.01284	val-mae:0.24748
# [30]	train-rmse:0.27537	train-mape:0.01204	train-mae:0.23200	val-rmse:0.29380	val-mape:0.01288	val-mae:0.24811
# [35]	train-rmse:0.27378	train-mape:0.01195	train-mae:0.23029	val-rmse:0.29495	val-mape:0.01292	val-mae:0.24886
# [40]	train-rmse:0.27200	train-mape:0.01185	train-mae:0.22840	val-rmse:0.29617	val-mape:0.01295	val-mae:0.24958
# [45]	train-rmse:0.27043	train-mape:0.01177	train-mae:0.22672	val-rmse:0.29716	val-mape:0.01298	val-mae:0.25016
# [50]	train-rmse:0.26896	train-mape:0.01168	train-mae:0.22511	val-rmse:0.29815	val-mape:0.01301	val-mae:0.25075
# [55]	train-rmse:0.26765	train-mape:0.01161	train-mae:0.22372	val-rmse:0.29906	val-mape:0.01304	val-mae:0.25134
# [60]	train-rmse:0.26623	train-mape:0.01153	train-mae:0.22221	val-rmse:0.29998	val-mape:0.01307	val-mae:0.25191
# [65]	train-rmse:0.26470	train-mape:0.01145	train-mae:0.22061	val-rmse:0.30101	val-mape:0.01311	val-mae:0.25255
# [70]	train-rmse:0.26337	train-mape:0.01138	train-mae:0.21922	val-rmse:0.30196	val-mape:0.01314	val-mae:0.25316
# [75]	train-rmse:0.26208	train-mape:0.01131	train-mae:0.21786	val-rmse:0.30285	val-mape:0.01317	val-mae:0.25374
# [80]	train-rmse:0.26069	train-mape:0.01123	train-mae:0.21642	val-rmse:0.30371	val-mape:0.01320	val-mae:0.25427
# [85]	train-rmse:0.25934	train-mape:0.01116	train-mae:0.21497	val-rmse:0.30464	val-mape:0.01323	val-mae:0.25486
# [90]	train-rmse:0.25811	train-mape:0.01109	train-mae:0.21370	val-rmse:0.30533	val-mape:0.01325	val-mae:0.25525
# [95]	train-rmse:0.25690	train-mape:0.01102	train-mae:0.21242	val-rmse:0.30614	val-mape:0.01327	val-mae:0.25575
# [100]	train-rmse:0.25574	train-mape:0.01096	train-mae:0.21117	val-rmse:0.30684	val-mape:0.01330	val-mae:0.25623
# [105]	train-rmse:0.25444	train-mape:0.01089	train-mae:0.20982	val-rmse:0.30763	val-mape:0.01332	val-mae:0.25676
# [110]	train-rmse:0.25325	train-mape:0.01082	train-mae:0.20858	val-rmse:0.30842	val-mape:0.01335	val-mae:0.25723
# [115]	train-rmse:0.25194	train-mape:0.01075	train-mae:0.20722	val-rmse:0.30903	val-mape:0.01337	val-mae:0.25760
# [120]	train-rmse:0.25067	train-mape:0.01068	train-mae:0.20589	val-rmse:0.30986	val-mape:0.01340	val-mae:0.25814
# [125]	train-rmse:0.24945	train-mape:0.01062	train-mae:0.20466	val-rmse:0.31046	val-mape:0.01341	val-mae:0.25848
# [130]	train-rmse:0.24825	train-mape:0.01055	train-mae:0.20343	val-rmse:0.31124	val-mape:0.01344	val-mae:0.25896
# [135]	train-rmse:0.24703	train-mape:0.01049	train-mae:0.20219	val-rmse:0.31199	val-mape:0.01346	val-mae:0.25947
# [140]	train-rmse:0.24588	train-mape:0.01043	train-mae:0.20103	val-rmse:0.31272	val-mape:0.01349	val-mae:0.25997
# [145]	train-rmse:0.24468	train-mape:0.01037	train-mae:0.19983	val-rmse:0.31339	val-mape:0.01351	val-mae:0.26036
# [150]	train-rmse:0.24351	train-mape:0.01031	train-mae:0.19864	val-rmse:0.31415	val-mape:0.01353	val-mae:0.26081
# [155]	train-rmse:0.24238	train-mape:0.01025	train-mae:0.19749	val-rmse:0.31478	val-mape:0.01355	val-mae:0.26119
# [160]	train-rmse:0.24112	train-mape:0.01018	train-mae:0.19624	val-rmse:0.31543	val-mape:0.01358	val-mae:0.26161
# [165]	train-rmse:0.24008	train-mape:0.01013	train-mae:0.19520	val-rmse:0.31603	val-mape:0.01359	val-mae:0.26194
# [170]	train-rmse:0.23899	train-mape:0.01007	train-mae:0.19412	val-rmse:0.31666	val-mape:0.01361	val-mae:0.26233
# [175]	train-rmse:0.23810	train-mape:0.01002	train-mae:0.19319	val-rmse:0.31717	val-mape:0.01363	val-mae:0.26268
# [180]	train-rmse:0.23718	train-mape:0.00998	train-mae:0.19227	val-rmse:0.31771	val-mape:0.01365	val-mae:0.26304
# [185]	train-rmse:0.23595	train-mape:0.00991	train-mae:0.19103	val-rmse:0.31834	val-mape:0.01367	val-mae:0.26350
# [190]	train-rmse:0.23490	train-mape:0.00986	train-mae:0.18996	val-rmse:0.31906	val-mape:0.01370	val-mae:0.26397
# [195]	train-rmse:0.23384	train-mape:0.00980	train-mae:0.18890	val-rmse:0.31957	val-mape:0.01371	val-mae:0.26428
# [199]	train-rmse:0.23312	train-mape:0.00976	train-mae:0.18816	val-rmse:0.32002	val-mape:0.01373	val-mae:0.26456

# %%
# %%capture output
for depth in [5, 10, 15, 20, 25, 30]:
    xgb_params = {
        'eta': 0.5, 
        'max_depth': depth,
        'min_child_weight': 1,
        
        'objective': 'reg:squarederror',
        'nthread': 8,
        'eval_metric': 'rmse',
        
        'seed': 42,
        'verbosity': 1,
    }
    model = xgb.train(xgb_params, dtrain, num_boost_round=201, verbose_eval=5, evals=watchlist)

    key = 'depth=%s' % (xgb_params['max_depth'])
    scores[key] = parse_xgb_output(output)

# %%
for depth in [5, 10, 15, 20, 25, 30]:
    cols = 'depth=' + str(depth)
    print(cols + '=====================')
    print(scores[cols].sort_values('val_rmse', ascending=True))
    print()
    print()
# Out:
# depth=5=====================
#     num_iter  train_rmse  val_rmse
# 16        80     0.28412   0.28588
# 49        40     0.28404   0.28588
# 48        35     0.28435   0.28589
# 17        85     0.28398   0.28589
# 19        95     0.28368   0.28590
# ..       ...         ...       ...
# 2         10     0.32898   0.32949
# 82         0     0.34887   0.34943
# 1          5     0.35464   0.35524
# 41         0     0.38412   0.38487
# 0          0     0.39372   0.39452
#
# [246 rows x 3 columns]
#
#
# depth=10=====================
#     num_iter  train_rmse  val_rmse
# 16        80     0.28412   0.28588
# 49        40     0.28404   0.28588
# 48        35     0.28435   0.28589
# 17        85     0.28398   0.28589
# 19        95     0.28368   0.28590
# ..       ...         ...       ...
# 2         10     0.32898   0.32949
# 82         0     0.34887   0.34943
# 1          5     0.35464   0.35524
# 41         0     0.38412   0.38487
# 0          0     0.39372   0.39452
#
# [246 rows x 3 columns]
#
#
# depth=15=====================
#     num_iter  train_rmse  val_rmse
# 16        80     0.28412   0.28588
# 49        40     0.28404   0.28588
# 48        35     0.28435   0.28589
# 17        85     0.28398   0.28589
# 19        95     0.28368   0.28590
# ..       ...         ...       ...
# 2         10     0.32898   0.32949
# 82         0     0.34887   0.34943
# 1          5     0.35464   0.35524
# 41         0     0.38412   0.38487
# 0          0     0.39372   0.39452
#
# [246 rows x 3 columns]
#
#
# depth=20=====================
#     num_iter  train_rmse  val_rmse
# 16        80     0.28412   0.28588
# 49        40     0.28404   0.28588
# 48        35     0.28435   0.28589
# 17        85     0.28398   0.28589
# 19        95     0.28368   0.28590
# ..       ...         ...       ...
# 2         10     0.32898   0.32949
# 82         0     0.34887   0.34943
# 1          5     0.35464   0.35524
# 41         0     0.38412   0.38487
# 0          0     0.39372   0.39452
#
# [246 rows x 3 columns]
#
#
# depth=25=====================
#     num_iter  train_rmse  val_rmse
# 16        80     0.28412   0.28588
# 49        40     0.28404   0.28588
# 48        35     0.28435   0.28589
# 17        85     0.28398   0.28589
# 19        95     0.28368   0.28590
# ..       ...         ...       ...
# 2         10     0.32898   0.32949
# 82         0     0.34887   0.34943
# 1          5     0.35464   0.35524
# 41         0     0.38412   0.38487
# 0          0     0.39372   0.39452
#
# [246 rows x 3 columns]
#
#
# depth=30=====================
#     num_iter  train_rmse  val_rmse
# 16        80     0.28412   0.28588
# 49        40     0.28404   0.28588
# 48        35     0.28435   0.28589
# 17        85     0.28398   0.28589
# 19        95     0.28368   0.28590
# ..       ...         ...       ...
# 2         10     0.32898   0.32949
# 82         0     0.34887   0.34943
# 1          5     0.35464   0.35524
# 41         0     0.38412   0.38487
# 0          0     0.39372   0.39452
#
# [246 rows x 3 columns]

# %%
# Train final model
full_train_dicts = df_full_train.to_dict(orient='records')
X_full_train = dv.transform(full_train_dicts)
test_dicts = df_test.to_dict(orient='records')
X_test = dv.transform(test_dicts)

# %%
dfulltrain = xgb.DMatrix(X_full_train, label=y_full_train, feature_names=features)
dtest = xgb.DMatrix(X_test, label=y_test, feature_names=features)

# %%
xgb_params = {
        'eta': 0.3, 
        'max_depth': 10,
        'min_child_weight': 1,
        
        'objective': 'reg:squarederror',
        'nthread': 8,
        'eval_metric': 'rmse',
        
        'seed': 42,
        'verbosity': 1,
    }
model = xgb.train(xgb_params, dfulltrain, num_boost_round=81, verbose_eval=5)

# %%
y_pred = model.predict(dtest)

# %%
rmse = round(root_mean_squared_error(y_test, y_pred),3)
r2 = round(r2_score(y_test, y_pred),3)
mape = round(mean_absolute_percentage_error(y_test, y_pred),3) * 100

# %%
print(f'rmse: {rmse}')
print(f'r2: {r2}')
print(f'mape: {mape}%')
# Out:
# rmse: 0.289
# r2: 0.491
# mape: 1.3%
